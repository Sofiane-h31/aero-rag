# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# %env HF_HOME=/projects/sig/sofiane_emofort/test4/aero-rag/hf_cache
# Out:
# env: HF_HOME=/projects/sig/sofiane_emofort/test4/aero-rag/hf_cache

# %%
# !cd /projects/sig/sofiane_emofort/test4/aero-rag && python scripts/01_build_index.py
# Out:
# [build] device: cuda
# README.md: 5.79kB [00:00, 7.68MB/s]
# ...
# asrs-aviation-reports-train.jsonl: 100%|█████| 270M/270M [00:04<00:00, 66.1MB/s]
# asrs-aviation-reports-validation.jsonl: 100%|█| 29.9M/29.9M [00:02<00:00, 13.2MB
# asrs-aviation-reports-test.jsonl: 100%|████| 33.3M/33.3M [00:01<00:00, 20.9MB/s]
# Generating train split: 100%|███| 38655/38655 [00:02<00:00, 16209.73 examples/s]
# Generating validation split: 100%|█| 4295/4295 [00:00<00:00, 16427.22 examples/s
# Generating test split: 100%|██████| 4773/4773 [00:00<00:00, 15661.69 examples/s]
# [data] loaded 4000 reports
# [ingest] 14619 chunks from 4000 reports
# ...
# config_sentence_transformers.json: 100%|████████| 124/124 [00:00<00:00, 355kB/s]
# README.md: 94.8kB [00:00, 50.6MB/s]
# sentence_bert_config.json: 100%|██████████████| 52.0/52.0 [00:00<00:00, 159kB/s]
# config.json: 100%|█████████████████████████████| 743/743 [00:00<00:00, 2.27MB/s]
# model.safetensors: 100%|█████████████████████| 133M/133M [00:01<00:00, 75.0MB/s]
# ...

# %%
# !python scripts/02_ask.py "What happens during a loss of cabin pressurization?"
# Out:
# [ask] loading pipeline (this downloads the model on first run)...
# ...
# config.json: 100%|█████████████████████████████| 663/663 [00:00<00:00, 1.60MB/s]
# tokenizer_config.json: 7.30kB [00:00, 11.0MB/s]
# vocab.json: 2.78MB [00:00, 42.9MB/s]
# merges.txt: 1.67MB [00:00, 55.4MB/s]
# tokenizer.json: 7.03MB [00:00, 104MB/s]
# model.safetensors.index.json: 27.8kB [00:00, 39.7MB/s]
# ...
# Fetching 4 files: 100%|███████████████████████████| 4/4 [00:59<00:00, 14.91s/it]
# Download complete: 100%|████████████████████| 15.2G/15.2G [01:00<00:00, 251MB/s]
# ...
# generation_config.json: 100%|███████████████████| 243/243 [00:00<00:00, 690kB/s]
#
# ...
# Q: What happens during a loss of cabin pressurization?
# ----------------------------------------------------------------------
# ...

# %%
# !python scripts/03_evaluate.py
# Out:
# [eval] loading pipeline...
# ...
# Loading weights: 100%|████████████████████████| 339/339 [00:04<00:00, 77.79it/s]
#
# Q: What are common causes of altitude deviations?
# A: Common causes of altitude deviations include issues with the aircraft's altitude measurement systems, such as the pitot static system being affected by water or other contaminants, and pilot focus on stabilizing the aircraft's heading or roll, which can divert attention from maintaining the correct altitude.
# Sources: RPT-00394, RPT-02160, RPT-02211, RPT-03038 | groundedness=0.791
#
# Q: How do crews handle an engine failure on departure?
# A: Based on the reports, crews handle an engine failure on departure by securing the engine, advising ATC, and diverting to the nearest airfield. If conditions do not allow for a safe approach and landing, they may elect to reduce power to idle and land gear up on the remaining runway to avoid an off-airport crash.
# ...
